# %%
import pickle
import os
import torch
import sys
from collections import Counter
from gensim.models import LdaModel
from bertopic import BERTopic
from topic_specificity import calculate_specificity_for_all_topics
from TopicSpecificityBerTopic.topic_specificity_bertopic import calculate_specificity_bertopic

# %%
collections = ['20ng', 'wsj', 'wiki']
lang_models = ['doc2vec','sbert','repllama']
topic_models = ['lda','bertopic']

# Single “source of truth” for optimal topic counts:
OPTIMAL_LDA_TOPICS = {
    'wsj': 50,
    'wiki': 80,
    '20ng': 70
}

# Placeholder for future Bertopic‐specific topic counts
OPTIMAL_BERTOPIC_TOPICS = {
    'wsj': 50,
    'wiki':80,
    '20ng':40
}

# %%
# -----------------------------------------------
# helper: fetch keywords  ------------------------
# -----------------------------------------------
def topic_keywords(tid, model, model_type, topn=10):
    if model_type == 'lda':
        return [w for w, _ in model.show_topic(tid, topn=topn)]
    return [w for w, _ in model.get_topic(tid)[:topn]]

# %%
# calculate LDA mapping
for i, coll in enumerate(collections):
    for topic_model in topic_models:
        # 1) Compute specificity
        if topic_model == 'lda':
            n_topics = OPTIMAL_LDA_TOPICS[coll]
            lda_path = os.path.join('Results', 'LDA', f"{coll}_lda{n_topics}.model")
            if not os.path.exists(lda_path):
                sys.exit(f"[ERROR] Cannot find LDA model: {lda_path}")
            lda = LdaModel.load(lda_path)

            corpus_path = os.path.join('Results', 'LDA', f"{coll}_corpus.pkl")
            if not os.path.exists(corpus_path):
                sys.exit(f"[ERROR] Corpus not found: {corpus_path}")
            corpus = pickle.load(open(corpus_path, 'rb'))

            scores = calculate_specificity_for_all_topics(
                model=lda,
                corpus=corpus,
                mode='lda',
                threshold_mode='gmm',
                specificity_mode='diff'
            )

        else:  # bertopic
            n_topics = OPTIMAL_BERTOPIC_TOPICS[coll]

            bt_path = os.path.join('Results', 'BERTOPIC', f"{coll}_bertopic_{n_topics}.model")
            if not os.path.exists(bt_path):
                sys.exit(f"[ERROR] BERTopic model not found: {bt_path}")
            bt = BERTopic.load(bt_path)

            scores = calculate_specificity_bertopic(
                bt,
                threshold_mode='gmm',
                specificity_mode='diff'
            )
        for lang_model in lang_models:
            # 2) Load mapping results for this (coll, lang_model, topic_model)
            map_file = os.path.join('Results', f"{coll}_{lang_model}_{topic_model}_{n_topics}_mapping.pkl")
            if lang_model == 'repllama' and coll in ['wsj','20ng']:
                map_file = os.path.join('Results', f"{coll}_{lang_model}_{topic_model}_mapping.pkl")
            if not os.path.exists(map_file):
                sys.exit(f"[ERROR] Mapping file not found: {map_file}")
            mappings = pickle.load(open(map_file, 'rb'))
            
            # 3) find the mapped topics and unmapped topics
            if topic_model == 'bertopic':
                real_n_topics = len(scores)
            else:
                real_n_topics = n_topics
            mapped_topics = [t for _, t in mappings]
            unmapped_topics = set(range(real_n_topics)) - set(mapped_topics)
            mapped_scores = [scores[t] for t in mapped_topics]
            unmapped_scores = [scores[t] for t in unmapped_topics]
            
            avg_mapped_score = sum(mapped_scores)/len(mapped_scores)
            avg_unmapped_score = sum(unmapped_scores)/len(unmapped_scores)
            
            # 4) print out the results
            # print(f"{coll}\t{topic_model}\t{lang_model}\t{avg_mapped_score:.4f}\t{avg_unmapped_score:.4f}")

            # -----------------------------------------------
            # 5) pick and print topics -----------------------
            # -----------------------------------------------
            # --- (a)  most-frequent mapped topics, tie-break by specificity
            freq = Counter(mapped_topics)                              # count hits
            top_mapped = sorted(freq,                                  # topic ids only
                                key=lambda t: (-freq[t], -scores[t]))  # primary ↓freq, secondary ↓score
            top_mapped = top_mapped[:3]

            # --- (b)  worst-specificity unmapped topics (unchanged)
            worst_unmapped = sorted(unmapped_topics, key=lambda t: scores[t])[:3]

            # --- (c) pretty print --------------------------------------
            print(f"—— {coll.upper()} | {topic_model.upper()} | {lang_model} ——")
            print(f"Avg specificity: mapped={avg_mapped_score:.4f}, "
                  f"unmapped={avg_unmapped_score:.4f}")

            print("\nTop-3 mapped topics (by frequency):")
            for rank, tid in enumerate(top_mapped, 1):
                kw = ", ".join(topic_keywords(tid,
                                              lda if topic_model == 'lda' else bt,
                                              topic_model))
                print(f"  {rank}. topic {tid:>3} | freq={freq[tid]:>3} | "
                      f"score={scores[tid]:.4f} | {kw}")

            print("\nWorst-3 unmapped topics (by specificity):")
            for rank, tid in enumerate(worst_unmapped, 1):
                kw = ", ".join(topic_keywords(tid,
                                              lda if topic_model == 'lda' else bt,
                                              topic_model))
                print(f"  {rank}. topic {tid:>3} | score={scores[tid]:.4f} | {kw}")

            print("-" * 60)
# Out:
# —— 20NG | LDA | doc2vec ——
# Avg specificity: mapped=0.0974, unmapped=0.0513
#
# Top-3 mapped topics (by frequency):
#   1. topic   2 | freq=  9 | score=0.1707 | think, go, like, know, time, get, want, thing, come, way
#   2. topic  22 | freq=  7 | score=0.1095 | god, jesus, church, christ, sin, love, christian, bible, lord, say
#   3. topic   0 | freq=  6 | score=0.0763 | space, earth, planet, moon, launch, solar, orbit, spacecraft, system, mission
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  24 | score=0.0240 | orthodox, son, slipper, till, candida, italy, beast, abstract, explore, presentation
#   2. topic  68 | score=0.0265 | keyboard, sub, rgb, virtual, thanx, custom, interior, silicon, plastic, fish
#   3. topic  54 | score=0.0278 | dry, push, playback, evolution, depth, clean, pop, educational, reverse, quit
# ------------------------------------------------------------
# —— 20NG | LDA | sbert ——
# Avg specificity: mapped=0.0954, unmapped=0.0448
#
# Top-3 mapped topics (by frequency):
#   1. topic  52 | freq=  8 | score=0.1053 | price, sell, new, sale, offer, good, buy, include, interested, like
#   2. topic  62 | freq=  7 | score=0.0930 | game, play, period, goal, score, shot, lead, pt, espn, win
#   3. topic  22 | freq=  6 | score=0.1095 | god, jesus, church, christ, sin, love, christian, bible, lord, say
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  24 | score=0.0240 | orthodox, son, slipper, till, candida, italy, beast, abstract, explore, presentation
#   2. topic  68 | score=0.0265 | keyboard, sub, rgb, virtual, thanx, custom, interior, silicon, plastic, fish
#   3. topic  54 | score=0.0278 | dry, push, playback, evolution, depth, clean, pop, educational, reverse, quit
# ------------------------------------------------------------
# —— 20NG | LDA | repllama ——
# Avg specificity: mapped=0.1180, unmapped=0.0521
#
# Top-3 mapped topics (by frequency):
#   1. topic   2 | freq= 21 | score=0.1707 | think, go, like, know, time, get, want, thing, come, way
#   2. topic  45 | freq= 18 | score=0.0586 | armenian, turkish, turk, turkey, russian, armenians, genocide, muslim, population, village
#   3. topic  15 | freq=  8 | score=0.1671 | window, problem, thank, help, run, work, know, try, use, like
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  24 | score=0.0240 | orthodox, son, slipper, till, candida, italy, beast, abstract, explore, presentation
#   2. topic  68 | score=0.0265 | keyboard, sub, rgb, virtual, thanx, custom, interior, silicon, plastic, fish
#   3. topic  54 | score=0.0278 | dry, push, playback, evolution, depth, clean, pop, educational, reverse, quit
# ------------------------------------------------------------
# —— 20NG | BERTOPIC | doc2vec ——
# Avg specificity: mapped=0.2000, unmapped=0.0587
#
# Top-3 mapped topics (by frequency):
#   1. topic   8 | freq= 13 | score=0.1913 | smiley, manhattan, beauchaine say, blow bronx, manhattan sea, bronx away, queen stay, say queen, stay blow, sink manhattan
#   2. topic   4 | freq=  8 | score=0.1870 | gun, homosexual, people, right, gay, drug, sex, moral, think, man
#   3. topic   2 | freq=  6 | score=0.1785 | car, price, new, bike, sell, sale, engine, good, appear, buy
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  35 | score=0.0143 | donation, copyright, shareware, john, notice, author, commercial, copy, fee, jan
#   2. topic  29 | score=0.0241 | helmet, pocket, jacket, piece, liner, fit, pant, woman, clothing, foam
#   3. topic  28 | score=0.0242 | mouse, driver, ball, problem, apple, mouse driver, window, roller, load, button
# ------------------------------------------------------------
# —— 20NG | BERTOPIC | sbert ——
# Avg specificity: mapped=0.1907, unmapped=0.0584
#
# Top-3 mapped topics (by frequency):
#   1. topic   8 | freq=  7 | score=0.1913 | smiley, manhattan, beauchaine say, blow bronx, manhattan sea, bronx away, queen stay, say queen, stay blow, sink manhattan
#   2. topic   2 | freq=  7 | score=0.1785 | car, price, new, bike, sell, sale, engine, good, appear, buy
#   3. topic   1 | freq=  6 | score=0.1914 | key, encryption, chip, clipper, government, use, message, algorithm, phone, system
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  35 | score=0.0143 | donation, copyright, shareware, john, notice, author, commercial, copy, fee, jan
#   2. topic  29 | score=0.0241 | helmet, pocket, jacket, piece, liner, fit, pant, woman, clothing, foam
#   3. topic  28 | score=0.0242 | mouse, driver, ball, problem, apple, mouse driver, window, roller, load, button
# ------------------------------------------------------------
# —— 20NG | BERTOPIC | repllama ——
# Avg specificity: mapped=0.2081, unmapped=0.0697
#
# Top-3 mapped topics (by frequency):
#   1. topic   0 | freq=  8 | score=0.4424 | game, team, play, player, win, year, season, hockey, league, hit
#   2. topic  30 | freq=  7 | score=0.0331 | battery, discharge, concrete, charge, acid, temperature, heat, lead, reaction, dirt
#   3. topic   1 | freq=  6 | score=0.1914 | key, encryption, chip, clipper, government, use, message, algorithm, phone, system
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  35 | score=0.0143 | donation, copyright, shareware, john, notice, author, commercial, copy, fee, jan
#   2. topic  29 | score=0.0241 | helmet, pocket, jacket, piece, liner, fit, pant, woman, clothing, foam
#   3. topic  28 | score=0.0242 | mouse, driver, ball, problem, apple, mouse driver, window, roller, load, button
# ------------------------------------------------------------
# —— WSJ | LDA | doc2vec ——
# Avg specificity: mapped=0.1046, unmapped=0.0775
#
# Top-3 mapped topics (by frequency):
#   1. topic  48 | freq=  6 | score=0.1037 | business, market, big, industry, time, go, small, cost, analyst, buy
#   2. topic  47 | freq=  5 | score=0.0824 | bush, party, political, campaign, election, democratic, president, state, candidate, vote
#   3. topic  40 | freq=  4 | score=0.1298 | like, people, time, know, day, go, come, get, man, old
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  13 | score=0.0229 | food, restaurant, franchise, chain, india, fast, spanish, taylor, knight, rice
#   2. topic  33 | score=0.0300 | san, pacific, california, francisco, southern, santa, railroad, georgia, diego, forest
#   3. topic  43 | score=0.0396 | insurance, steel, life, insurer, cellular, premium, policy, national, corp, industry
# ------------------------------------------------------------
# —— WSJ | LDA | sbert ——
# Avg specificity: mapped=0.1289, unmapped=0.0748
#
# Top-3 mapped topics (by frequency):
#   1. topic  28 | freq=  8 | score=0.1693 | president, executive, chief, vice, officer, chairman, name, director, old, board
#   2. topic  24 | freq=  6 | score=0.2029 | share, stock, common, exchange, cent, trading, close, outstanding, inc, dividend
#   3. topic  46 | freq=  4 | score=0.0926 | drug, health, medical, care, hospital, research, patient, fda, test, study
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  13 | score=0.0229 | food, restaurant, franchise, chain, india, fast, spanish, taylor, knight, rice
#   2. topic  33 | score=0.0300 | san, pacific, california, francisco, southern, santa, railroad, georgia, diego, forest
#   3. topic  43 | score=0.0396 | insurance, steel, life, insurer, cellular, premium, policy, national, corp, industry
# ------------------------------------------------------------
# —— WSJ | LDA | repllama ——
# Avg specificity: mapped=0.1329, unmapped=0.0798
#
# Top-3 mapped topics (by frequency):
#   1. topic  39 | freq= 12 | score=0.1428 | sell, agreement, group, inc, unit, corp, sale, agree, acquire, transaction
#   2. topic  24 | freq=  6 | score=0.2029 | share, stock, common, exchange, cent, trading, close, outstanding, inc, dividend
#   3. topic  28 | freq=  6 | score=0.1693 | president, executive, chief, vice, officer, chairman, name, director, old, board
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  13 | score=0.0229 | food, restaurant, franchise, chain, india, fast, spanish, taylor, knight, rice
#   2. topic  33 | score=0.0300 | san, pacific, california, francisco, southern, santa, railroad, georgia, diego, forest
#   3. topic  43 | score=0.0396 | insurance, steel, life, insurer, cellular, premium, policy, national, corp, industry
# ------------------------------------------------------------
# —— WSJ | BERTOPIC | doc2vec ——
# Avg specificity: mapped=0.1832, unmapped=0.1426
#
# Top-3 mapped topics (by frequency):
#   1. topic   0 | freq=  6 | score=0.5490 | share, say, company, million, stock, year, market, inc, new, sale
#   2. topic   1 | freq=  5 | score=0.2320 | bank, bond, rate, dollar, yield, treasury, issue, million, price, market
#   3. topic   3 | freq=  4 | score=0.1928 | rise, increase, rate, adjust, month, year, unemployment, economist, consumer, price
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  38 | score=0.0121 | constitution, convention, church, woman, constitutional, madison, amendment, hofmann, people, document
#   2. topic  31 | score=0.0141 | pri, salinas, mexico, election, pinochet, party, opposition, mexican, gen, haiti
#   3. topic  28 | score=0.0162 | south, africa, south africa, black, african, apartheid, anc, south african, government, white
# ------------------------------------------------------------
# —— WSJ | BERTOPIC | sbert ——
# Avg specificity: mapped=0.2640, unmapped=0.1534
#
# Top-3 mapped topics (by frequency):
#   1. topic   0 | freq= 17 | score=0.5490 | share, say, company, million, stock, year, market, inc, new, sale
#   2. topic   3 | freq=  6 | score=0.1928 | rise, increase, rate, adjust, month, year, unemployment, economist, consumer, price
#   3. topic  23 | freq=  4 | score=0.0697 | kodak, polaroid, cannon, shamrock, film, camera, tape, recorder, say, video
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  38 | score=0.0121 | constitution, convention, church, woman, constitutional, madison, amendment, hofmann, people, document
#   2. topic  31 | score=0.0141 | pri, salinas, mexico, election, pinochet, party, opposition, mexican, gen, haiti
#   3. topic  28 | score=0.0162 | south, africa, south africa, black, african, apartheid, anc, south african, government, white
# ------------------------------------------------------------
# —— WSJ | BERTOPIC | repllama ——
# Avg specificity: mapped=0.3411, unmapped=0.1349
#
# Top-3 mapped topics (by frequency):
#   1. topic   0 | freq= 26 | score=0.5490 | share, say, company, million, stock, year, market, inc, new, sale
#   2. topic  46 | freq=  4 | score=0.0251 | moslem, islam, islamic, religion, ayatollah, koran, iran, mosque, khomeini, indonesia
#   3. topic   1 | freq=  3 | score=0.2320 | bank, bond, rate, dollar, yield, treasury, issue, million, price, market
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  38 | score=0.0121 | constitution, convention, church, woman, constitutional, madison, amendment, hofmann, people, document
#   2. topic  31 | score=0.0141 | pri, salinas, mexico, election, pinochet, party, opposition, mexican, gen, haiti
#   3. topic  30 | score=0.0158 | census, woman, population, bureau, family, census bureau, household, income, man, child
# ------------------------------------------------------------
# —— WIKI | LDA | doc2vec ——
# Avg specificity: mapped=0.1048, unmapped=0.0644
#
# Top-3 mapped topics (by frequency):
#   1. topic  24 | freq=  8 | score=0.1462 | empire, roman, emperor, war, city, army, king, battle, byzantine, rome
#   2. topic  14 | freq=  8 | score=0.1061 | philosophy, theory, knowledge, view, philosopher, school, idea, truth, nature, world
#   3. topic  43 | freq=  6 | score=0.0960 | oil, water, gas, fuel, air, increase, fire, energy, carbon, chemical
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  60 | score=0.0171 | bridge, arch, build, river, stone, aqueduct, span, construct, roman, welding
#   2. topic  76 | score=0.0257 | madhava, motto, sine, trigonometric, series, school, seal, magister, arc, acta
#   3. topic  48 | score=0.0278 | instrument, curl, cosmetic, musical, rope, perfume, hair, hand, scallop, ensemble
# ------------------------------------------------------------
# —— WIKI | LDA | sbert ——
# Avg specificity: mapped=0.1106, unmapped=0.0621
#
# Top-3 mapped topics (by frequency):
#   1. topic  12 | freq=  5 | score=0.1052 | roman, rome, empire, italy, emperor, latin, romans, greek, italian, city
#   2. topic  66 | freq=  5 | score=0.1046 | university, publish, society, science, laplace, mathematic, research, write, book, professor
#   3. topic  16 | freq=  5 | score=0.0965 | culture, cultural, people, group, country, right, human, united, social, community
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  60 | score=0.0171 | bridge, arch, build, river, stone, aqueduct, span, construct, roman, welding
#   2. topic  76 | score=0.0257 | madhava, motto, sine, trigonometric, series, school, seal, magister, arc, acta
#   3. topic  48 | score=0.0278 | instrument, curl, cosmetic, musical, rope, perfume, hair, hand, scallop, ensemble
# ------------------------------------------------------------
# —— WIKI | LDA | repllama ——
# Avg specificity: mapped=0.1182, unmapped=0.0657
#
# Top-3 mapped topics (by frequency):
#   1. topic  45 | freq=  8 | score=0.2045 | language, italian, dialect, speak, latin, romance, french, vowel, word, italy
#   2. topic  25 | freq=  6 | score=0.1896 | integral, function, theory, series, theorem, set, problem, calculus, mathematic, mathematical
#   3. topic  24 | freq=  6 | score=0.1462 | empire, roman, emperor, war, city, army, king, battle, byzantine, rome
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  60 | score=0.0171 | bridge, arch, build, river, stone, aqueduct, span, construct, roman, welding
#   2. topic  48 | score=0.0278 | instrument, curl, cosmetic, musical, rope, perfume, hair, hand, scallop, ensemble
#   3. topic  55 | score=0.0280 | buddha, buddhist, chinese, buddhism, han, indian, text, ruler, shen, dynasty
# ------------------------------------------------------------
# —— WIKI | BERTOPIC | doc2vec ——
# Avg specificity: mapped=0.1397, unmapped=0.1289
#
# Top-3 mapped topics (by frequency):
#   1. topic   0 | freq= 12 | score=0.2141 | roman, rome, emperor, empire, city, caesar, century, senate, romans, military
#   2. topic  30 | freq=  5 | score=0.0745 | plant, glossary, taxonomy, flora, organism, specie, animal, biology, botany, linnaeus
#   3. topic   3 | freq=  4 | score=0.2977 | italian, sardinian, language, dialect, catalan, speak, italy, calabria, occitan, romance
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  36 | score=0.0329 | sexual, gender, woman, sex, rape, transgender, man, sexual orientation, feminist, orientation
#   2. topic  73 | score=0.0331 | assyrian, babylon, king, city, assyria, babylonian, nubian, makuria, baghdad, antioch
#   3. topic  69 | score=0.0334 | vector, vector field, theorem, field, differential, gradient, integral, curl, exterior, divergence
# ------------------------------------------------------------
# —— WIKI | BERTOPIC | sbert ——
# Avg specificity: mapped=0.1578, unmapped=0.1085
#
# Top-3 mapped topics (by frequency):
#   1. topic   0 | freq= 14 | score=0.2141 | roman, rome, emperor, empire, city, caesar, century, senate, romans, military
#   2. topic   4 | freq=  7 | score=0.1112 | greek, byzantine, empire, constantinople, greece, period, city, century, emperor, roman
#   3. topic   2 | freq=  5 | score=0.3033 | letter, vowel, syllable, alphabet, accent, consonant, word, sound, greek, language
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  56 | score=0.0325 | milk, animal, farm, feed, hive, bee, cow, livestock, dairy, production
#   2. topic  73 | score=0.0331 | assyrian, babylon, king, city, assyria, babylonian, nubian, makuria, baghdad, antioch
#   3. topic  55 | score=0.0333 | oil, fuel, gasoline, bituman, diesel, sand, petroleum, asphalt, crude, refinery
# ------------------------------------------------------------
# —— WIKI | BERTOPIC | repllama ——
# Avg specificity: mapped=0.1343, unmapped=0.1183
#
# Top-3 mapped topics (by frequency):
#   1. topic  19 | freq= 10 | score=0.0727 | integral, function, antiderivative, integration, theorem, integrable, lebesgue, substitution, cos, continuous
#   2. topic   0 | freq=  8 | score=0.2141 | roman, rome, emperor, empire, city, caesar, century, senate, romans, military
#   3. topic  47 | freq=  8 | score=0.1078 | shen, china, chinese, dynasty, mao, confucian, confucius, confucianism, han, polo
#
# Worst-3 unmapped topics (by specificity):
#   1. topic  36 | score=0.0329 | sexual, gender, woman, sex, rape, transgender, man, sexual orientation, feminist, orientation
#   2. topic  73 | score=0.0331 | assyrian, babylon, king, city, assyria, babylonian, nubian, makuria, baghdad, antioch
#   3. topic  55 | score=0.0333 | oil, fuel, gasoline, bituman, diesel, sand, petroleum, asphalt, crude, refinery
# ------------------------------------------------------------
