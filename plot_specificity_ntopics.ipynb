# %%
from Visualisation.plot_specificity import plot_top10_specificity, plot_specificity
import matplotlib.pyplot as plt

# %%
path = 'Results/BERTOPIC/20ng_bertopic_specificity.pkl'
plot_specificity(path)
plt.savefig("Results/Figures/20ng_bertopic_elbow.pdf")

# %%
path = 'Results/BERTOPIC/wiki_bertopic_specificity.pkl'
plot_specificity(path)
plt.savefig("Results/Figures/wiki_bertopic_elbow.pdf")

# %%
path = 'Results/BERTOPIC/wsj_bertopic_specificity.pkl'
plot_specificity(path)
plt.savefig("Results/Figures/wsj_bertopic_elbow.pdf")
