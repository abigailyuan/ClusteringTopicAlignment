# %%
from Visualisation.plot_specificity import plot_top10_specificity, plot_specificity
import matplotlib.pyplot as plt

# %%
path = 'Results/LDA/20ng_lda_spec.pkl'
plot_specificity(path)
plt.savefig("Results/Figures/20ng_lda_elbow.pdf")

# %%
path = 'Results/LDA/wiki_lda_spec.pkl'
plot_specificity(path)
plt.savefig("Results/Figures/wiki_lda_elbow.pdf")

# %%
path = 'Results/LDA/wsj_lda_spec.pkl'
plot_specificity(path)
plt.savefig("Results/Figures/wsj_lda_elbow.pdf")
